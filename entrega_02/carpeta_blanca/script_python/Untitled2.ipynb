# %%
import pandas as pd

url = "https://raw.githubusercontent.com/rreennaattoo/repo_proyectoX/refs/heads/main/entrega_02/carpeta_blanca/Base%20de%20datos%20Blanca%20R%C3%ADos%20Entrega%2002%20Gr%C3%A1fica.csv"
df = pd.read_csv(url, sep=';')
(df.head())
# Out:
#                            Nombre  Año de estreno  Duración   \
# 0          ¿Quien tiene la culpa?            2025        103
# 1               Patio de Chacales            2025        108
# 2                 ¿Cuándo te vas?            2025         82
# 3  Desconectados 2: Reconectados             2025        103
# 4              La llama interior             2025         73
#
#                Género  Calificación IMDB
# 0             Comedia                5,4
# 1       Drama, terror                7,2
# 2             Comedia                6,7
# 3    Comedia, familia                5,0
# 4  Fantasía, misterio  Sin calificación
